# %% [markdown]
# # Searching EMA RWD Studies in other databases
# We will search for EMA RWD Studies in [ClinicalTrials.gov](https://www.clinicaltrials.gov) and [Pubmed](https://pubmed.ncbi.nlm.nih.gov/).
#
# <small>**NOTE:** This notebook was supposed to be used to find other references based on the metadata of each study.</small>
#
# <small>**NOTE:** Not used for final analysis. Out of scope.</small>

# %% [markdown]
# First import the needed libraries...

# %%
import pandas as pd
from pymed import PubMed
import requests
from tqdm.notebook import tqdm

from urllib.parse import quote_plus

# %% [markdown]
# ...and the data:

# %%
exported = pd.read_excel('../database_migration/converted_ema-rwd_2024-02-21.xlsx').set_index('eu_pas_register_number').sort_index()

# %% [markdown]
# We will just focus on the required RMP (category 1 and 2) studies and try to extract the acronym from the title.
#
# **NOTE:** Acronym was once a seperate field in the EU PAS Register study. It has been merged with the title in the new EMA RWD database.

# %%
base = exported.assign(
    acronym=lambda x : x['title'].str.extract(r'\((?P<acronym>[^\(\)]+)\)\s*$')
)[exported['risk_management_plan'].isin([
    'EU RMP category 1 (imposed as condition of marketing authorisation)',
    'EU RMP category 2 (specific obligation of marketing authorisation)'
])].filter(regex='title|references|has|^url$|acronym|regulatory_procedure_number')

base
# Out:
#                                                                     title  \
# eu_pas_register_number
# 2165                    Post-Authorisation Safety Study of Esbriet® (P...
# 2181                    Study of Acute Liver Transplant: A study of NS...
# 2196                    Prospective controlled cohort study on the saf...
# 2857                    A Multicenter Cohort Study of the Short and Lo...
# 3142                    A Safety and Pharmacokinetic study in Real-lif...
# ...                                                                   ...
# 103852                  Non-interventional, post-authorization efficac...
# 103855                  Non-interventional, post-authorization safety ...
# 105358                  A Registry of Patients Treated with Fintepla (...
# 105422                  A Two-Part, International, Real-World, Observa...
# 106066                  An Observational Post-authorization Long-term ...
#
#                                                                   url  \
# eu_pas_register_number
# 2165                     https://catalogues.ema.europa.eu/study/23388
# 2181                     https://catalogues.ema.europa.eu/study/40864
# 2196                     https://catalogues.ema.europa.eu/study/41500
# 2857                     https://catalogues.ema.europa.eu/study/35221
# 3142                     https://catalogues.ema.europa.eu/study/47210
# ...                                                               ...
# 103852                  https://catalogues.ema.europa.eu/study/103853
# 103855                  https://catalogues.ema.europa.eu/study/103856
# 105358                  https://catalogues.ema.europa.eu/study/105359
# 105422                  https://catalogues.ema.europa.eu/study/105423
# 106066                  https://catalogues.ema.europa.eu/study/106067
#
#                        regulatory_procedure_number  \
# eu_pas_register_number
# 2165                                           NaN
# 2181                                           NaN
# 2196                                           NaN
# 2857                                           NaN
# 3142                                           NaN
# ...                                            ...
# 103852                       EMEA/H/C/PSP/S/0098.1
# 103855                       EMEA/H/C/PSP/S/0098.1
# 105358                             EMEA/H/C/003933
# 105422                     EMEA/H/C/005352/SOB/002
# 106066                                         NaN
#
#                                                                references  \
# eu_pas_register_number
# 2165                                                                  NaN
# 2181                    https://doi.org/10.1002/pds.3204; https://doi....
# 2196                                                                  NaN
# 2857                    https://doi.org/10.1093/jac/dkw225; https://do...
# 3142                           https://doi.org/10.1007/s40264-019-00821-6
# ...                                                                   ...
# 103852                                                                NaN
# 103855                                                                NaN
# 105358                                                                NaN
# 105422                                                                NaN
# 106066                                                                NaN
#
#                                   acronym
# eu_pas_register_number
# 2165                             PASSPORT
# 2181                               SALT-I
# 2196                               PRO-E2
# 2857                                MYCOS
# 3142                                  NaN
# ...                                   ...
# 103852                         CA082-1105
# 103855                    JCAR017-BCM-005
# 105358                  TAPESTRY Registry
# 105422                    PTC-AADC-MA-406
# 106066                        CSL222_4001
#
# [166 rows x 5 columns]

# %% [markdown]
# ## Searching in ClinicalTrials.gov
# We will now search the ClinicalTrials.gov database in this order:
#
# 1. EU PAS Register Number
# 1. Title
# 1. Regulatory Procedure Number (if applicable)
# 1. Acronym (if applicable)

# %%
rest_search_url = "https://clinicaltrials.gov/api/v2/studies?format=json&markupFormat=markdown&countTotal=true&pageSize=15"
id_search_query = '"EUPAS{0}" OR "Eupas{0}" OR "eupas{0}" OR (("EUPAS" OR "Eupas" OR "Eu Pas" OR "EU PAS" OR "EU Pas" OR "Eu PAS") AND "{0}")'

nct_df = pd.DataFrame().assign(
    eu_pas_register_number=pd.NA,
    nct_total_count=pd.NA,
    nct_url=pd.NA,
    nct_id=pd.NA,
    nct_state=pd.NA,
    nct_first_posted=pd.NA,
    nct_title=pd.NA,
    nct_acronym=pd.NA,
    nct_lead_sponsor=pd.NA,
    nct_pmid_references=pd.NA,
    nct_status_code=pd.NA,
    nct_search_term=pd.NA,
)

for [id, title, references, rpn, references, acronym] in tqdm(base.reset_index().values, total=len(base)):

    search_term = pd.NA

    def add_fail_entry(df, status_code, search_term):
        df = pd.concat([ 
            df,
            pd.DataFrame([[
                id, status_code, search_term
            ]], columns=['eu_pas_register_number', 'nct_status_code', 'nct_search_term'])
        ], ignore_index=True)
        return df
    
    search_term = 'eu_pas_register_number'
    response = requests.get(f'{rest_search_url}&query.id={quote_plus(id_search_query.format(id))}')
    if response.status_code != 200:
        nct_df = add_fail_entry(nct_df, response.status_code, search_term)
        continue
    clinical_trials_studies = response.json()

    if not clinical_trials_studies['studies']:
        
        search_term = 'title'
        response = requests.get(f'{rest_search_url}&query.titles={quote_plus(title)}')
        if response.status_code != 200:
            nct_df = add_fail_entry(nct_df, response.status_code, search_term)
            continue
        clinical_trials_studies = response.json()
        
        if not clinical_trials_studies['studies']:

            if pd.notna(rpn):
                search_term = 'regulatory_procedure_number'
                response = requests.get(f'{rest_search_url}&query.id={quote_plus(rpn)}')
                if response.status_code != 200:
                    nct_df = add_fail_entry(nct_df, response.status_code, search_term)
                    continue
                clinical_trials_studies = response.json()
                
            
            if pd.notna(acronym) and not clinical_trials_studies['studies']:
                search_term = 'acronym'
                response = requests.get(f'{rest_search_url}&query.id={quote_plus(acronym)}')
                if response.status_code != 200:
                    nct_df = add_fail_entry(nct_df, response.status_code, search_term)
                    continue
                clinical_trials_studies = response.json()
                
            
    if not clinical_trials_studies['studies']:
        search_term = pd.NA
    
    total_count = clinical_trials_studies['totalCount']

    nct_urls = '; '.join(
        f"https://www.clinicaltrials.gov/study/{study['protocolSection']['identificationModule']['nctId']}"
        for study in clinical_trials_studies['studies']
    )

    nct_ids = '; '.join(
        study['protocolSection']['identificationModule']['nctId']
        for study in clinical_trials_studies['studies']
    )

    nct_states = '; '.join(
        study['protocolSection']['statusModule']['overallStatus']
        for study in clinical_trials_studies['studies']
    )

    nct_first_posted = '; '.join(
        study['protocolSection']['statusModule']['studyFirstPostDateStruct']['date']
        for study in clinical_trials_studies['studies']
    )

    nct_titles = '; '.join(
        study['protocolSection']['identificationModule'].get('officialTitle',
            study['protocolSection']['identificationModule']['briefTitle']
        )
        for study in clinical_trials_studies['studies']
    )

    nct_acronyms = '; '.join(
        study['protocolSection']['identificationModule'].get('acronym', 'n.a.')
        for study in clinical_trials_studies['studies']
    )

    nct_sponsors = '; '.join(
        study['protocolSection']['sponsorCollaboratorsModule']['leadSponsor']['name']
        for study in clinical_trials_studies['studies']
    )

    nct_references = []
    for study in clinical_trials_studies['studies']:
        if study['protocolSection'].get('referencesModule', dict()).get('references'):
            nct_references.append([
                reference['pmid']
                for reference in study['protocolSection']['referencesModule']['references']
                if reference.get('pmid')
            ] or ['n.a.'])
        else:
            nct_references.append(['n.a.'])
    nct_references = '; '.join([', '.join(references) for references in nct_references])

    nct_df = pd.concat([ 
        nct_df,
        pd.DataFrame([[
            id,
            total_count,
            nct_urls,
            nct_ids,
            nct_states,
            nct_first_posted,
            nct_titles,
            nct_acronyms,
            nct_sponsors,
            nct_references,
            response.status_code,
            search_term
        ]], columns=nct_df.columns)
    ], ignore_index=True)

nct_df = nct_df.set_index('eu_pas_register_number')
nct_df
# Out:
#   0%|          | 0/166 [00:00<?, ?it/s]
#                        nct_total_count  \
# eu_pas_register_number
# 2165                                 5
# 2181                                 0
# 2196                                 1
# 2857                                 1
# 3142                                 0
# ...                                ...
# 103852                               0
# 103855                               0
# 105358                               0
# 105422                               0
# 106066                               1
#
#                                                                   nct_url  \
# eu_pas_register_number
# 2165                    https://www.clinicaltrials.gov/study/NCT062742...
# 2181
# 2196                     https://www.clinicaltrials.gov/study/NCT01650168
# 2857                     https://www.clinicaltrials.gov/study/NCT01686607
# 3142
# ...                                                                   ...
# 103852
# 103855
# 105358
# 105422
# 106066                   https://www.clinicaltrials.gov/study/NCT06008938
#
#                                                                    nct_id  \
# eu_pas_register_number
# 2165                    NCT06274294; NCT04716023; NCT03068468; NCT0397...
# 2181
# 2196                                                          NCT01650168
# 2857                                                          NCT01686607
# 3142
# ...                                                                   ...
# 103852
# 103855
# 105358
# 105422
# 106066                                                        NCT06008938
#
#                                                                 nct_state  \
# eu_pas_register_number
# 2165                    NOT_YET_RECRUITING; UNKNOWN; TERMINATED; COMPL...
# 2181
# 2196                                                            COMPLETED
# 2857                                                            COMPLETED
# 3142
# ...                                                                   ...
# 103852
# 103855
# 105358
# 105422
# 106066                                                         RECRUITING
#
#                                                          nct_first_posted  \
# eu_pas_register_number
# 2165                    2024-02-23; 2021-01-20; 2017-03-01; 2019-06-07...
# 2181
# 2196                                                           2012-07-26
# 2857                                                           2012-09-18
# 3142
# ...                                                                   ...
# 103852
# 103855
# 105358
# 105422
# 106066                                                         2023-08-24
#
#                                                                 nct_title  \
# eu_pas_register_number
# 2165                    The "PASSPORT Trial": Pharmacokinetics, Effica...
# 2181
# 2196                    Prospective Controlled Cohort Study on the Saf...
# 2857                    A Multicenter Cohort Study of the Short and Lo...
# 3142
# ...                                                                   ...
# 103852
# 103855
# 105358
# 105422
# 106066                  An Observational Post-authorization Long-term ...
#
#                                                          nct_acronym  \
# eu_pas_register_number
# 2165                    PASSPORT; PASSPORT; PASSPORT; PASSPoRT; n.a.
# 2181
# 2196                                                          PRO-E2
# 2857                                                           MYCOS
# 3142
# ...                                                              ...
# 103852
# 103855
# 105358
# 105422
# 106066                                                  IX-TEND 4001
#
#                                                          nct_lead_sponsor  \
# eu_pas_register_number
# 2165                    CMC Ambroise Paré; Imperial College London; Bi...
# 2181
# 2196                    Center for Epidemiology and Health Research, G...
# 2857                                          Astellas Pharma Europe B.V.
# 3142
# ...                                                                   ...
# 103852
# 103855
# 105358
# 105422
# 106066                                                        CSL Behring
#
#                                                       nct_pmid_references  \
# eu_pas_register_number
# 2165                    33676969, 35673354; n.a.; 34736158, 34385707; ...
# 2181
# 2196                                                                 n.a.
# 2857                                                                 n.a.
# 3142
# ...                                                                   ...
# 103852
# 103855
# 105358
# 105422
# 106066                                                               n.a.
#
#                        nct_status_code         nct_search_term
# eu_pas_register_number
# 2165                               200                 acronym
# 2181                               200                     NaN
# 2196                               200                   title
# 2857                               200                   title
# 3142                               200                     NaN
# ...                                ...                     ...
# 103852                             200                     NaN
# 103855                             200                     NaN
# 105358                             200                     NaN
# 105422                             200                     NaN
# 106066                             200  eu_pas_register_number
#
# [166 rows x 11 columns]

# %% [markdown]
# We can save and reload this Dataframe:

# %%
nct_df.to_excel('rmp1&2_nct.xlsx', sheet_name='nct')

# %%
nct_df = pd.read_excel('rmp1&2_nct.xlsx', sheet_name='nct', index_col='eu_pas_register_number')
nct_df.head()
# Out:
#                         nct_total_count  \
# eu_pas_register_number
# 2165                                5.0
# 2181                                0.0
# 2196                                1.0
# 2857                                1.0
# 3142                                0.0
#
#                                                                   nct_url  \
# eu_pas_register_number
# 2165                    https://www.clinicaltrials.gov/study/NCT062742...
# 2181                                                                  NaN
# 2196                     https://www.clinicaltrials.gov/study/NCT01650168
# 2857                     https://www.clinicaltrials.gov/study/NCT01686607
# 3142                                                                  NaN
#
#                                                                    nct_id  \
# eu_pas_register_number
# 2165                    NCT06274294; NCT04716023; NCT03068468; NCT0397...
# 2181                                                                  NaN
# 2196                                                          NCT01650168
# 2857                                                          NCT01686607
# 3142                                                                  NaN
#
#                                                                 nct_state  \
# eu_pas_register_number
# 2165                    NOT_YET_RECRUITING; UNKNOWN; TERMINATED; COMPL...
# 2181                                                                  NaN
# 2196                                                            COMPLETED
# 2857                                                            COMPLETED
# 3142                                                                  NaN
#
#                                                          nct_first_posted  \
# eu_pas_register_number
# 2165                    2024-02-23; 2021-01-20; 2017-03-01; 2019-06-07...
# 2181                                                                  NaN
# 2196                                                           2012-07-26
# 2857                                                           2012-09-18
# 3142                                                                  NaN
#
#                                                                 nct_title  \
# eu_pas_register_number
# 2165                    The "PASSPORT Trial": Pharmacokinetics, Effica...
# 2181                                                                  NaN
# 2196                    Prospective Controlled Cohort Study on the Saf...
# 2857                    A Multicenter Cohort Study of the Short and Lo...
# 3142                                                                  NaN
#
#                                                          nct_acronym  \
# eu_pas_register_number
# 2165                    PASSPORT; PASSPORT; PASSPORT; PASSPoRT; n.a.
# 2181                                                             NaN
# 2196                                                          PRO-E2
# 2857                                                           MYCOS
# 3142                                                             NaN
#
#                                                          nct_lead_sponsor  \
# eu_pas_register_number
# 2165                    CMC Ambroise Paré; Imperial College London; Bi...
# 2181                                                                  NaN
# 2196                    Center for Epidemiology and Health Research, G...
# 2857                                          Astellas Pharma Europe B.V.
# 3142                                                                  NaN
#
#                                                       nct_pmid_references  \
# eu_pas_register_number
# 2165                    33676969, 35673354; n.a.; 34736158, 34385707; ...
# 2181                                                                  NaN
# 2196                                                                 n.a.
# 2857                                                                 n.a.
# 3142                                                                  NaN
#
#                         nct_status_code nct_search_term
# eu_pas_register_number
# 2165                                200         acronym
# 2181                                200             NaN
# 2196                                200           title
# 2857                                200           title
# 3142                                200             NaN

# %% [markdown]
# ## Searching in Pubmed

# %% [markdown]
# We will use the `pymed` library to search for studies with the Pubmed API.
#
# We will search by NCT ID and EU PAS Register number.

# %%
pubmed = PubMed(tool="EmaRwdSearcher", email="pedram.ramezani@charite.de")

eupas_id_search_term_template = '((eupas OR "eu pas") AND {id}) OR eupas{id}'
article_info = []

for [id, title, references, rpn, references, acronym] in tqdm(base.reset_index().values, total=len(base)):

    search_term = 'eu_pas_register_number'
    results = pubmed.query(eupas_id_search_term_template.format(id=id), max_results=100)
    if not results:
        search_term = 'title'
        results = pubmed.query(title, max_results=100)
        if not results and rpn:
            search_term = 'regulatory_procedure_number'
            results = pubmed.query(rpn, max_results=100)
    
    article_list = []
    for article in results:
        article_dict = article.toDict()
        article_list.append(article_dict)

    for article in article_list:
        # Sometimes article['pubmed_id'] contains list separated with comma - take first pubmedId in that list - thats article pubmedId
        pubmedId = article['pubmed_id'].partition('\n')[0]
        
        article_info.append({
            'eu_pas_register_number': id,
            'pubmed_id': pubmedId,
            'pubmed_url': f'https://pubmed.ncbi.nlm.nih.gov/{pubmedId}/',
            'pubmed_title': article['title'],
            'pubmed_publication_date': article['publication_date'],
            'pubmed_search_term': search_term
        })

articles_df = pd.DataFrame.from_dict(article_info)

articles_df
# Out:
#   0%|          | 0/166 [00:00<?, ?it/s]
#     eu_pas_register_number pubmed_id  \
# 0                     3142  31069703
# 1                     4270  29748252
# 2                     5812  38888495
# 3                     6942  33964945
# 4                     9361  32140554
# 5                    11384  35766393
# 6                    12330  31749061
# 7                    13514  38459585
# 8                    13514  37051203
# 9                    16927  34801015
# 10                   31153  36878196
#
#                                    pubmed_url  \
# 0   https://pubmed.ncbi.nlm.nih.gov/31069703/
# 1   https://pubmed.ncbi.nlm.nih.gov/29748252/
# 2   https://pubmed.ncbi.nlm.nih.gov/38888495/
# 3   https://pubmed.ncbi.nlm.nih.gov/33964945/
# 4   https://pubmed.ncbi.nlm.nih.gov/32140554/
# 5   https://pubmed.ncbi.nlm.nih.gov/35766393/
# 6   https://pubmed.ncbi.nlm.nih.gov/31749061/
# 7   https://pubmed.ncbi.nlm.nih.gov/38459585/
# 8   https://pubmed.ncbi.nlm.nih.gov/37051203/
# 9   https://pubmed.ncbi.nlm.nih.gov/34801015/
# 10  https://pubmed.ncbi.nlm.nih.gov/36878196/
#
#                                          pubmed_title pubmed_publication_date  \
# 0   Bismuth Concentrations in Patients Treated in ...              2019-05-10
# 1   Data from the US and UK cystic fibrosis regist...              2018-05-12
# 2   Long-term safety of hyaluronidase-facilitated ...              2024-06-18
# 3   Longitudinal study based on a safety registry ...              2021-05-10
# 4   A European, multicentre, observational, post-a...              2020-03-07
# 5   Use and safety of aprotinin in routine clinica...              2022-06-30
# 6   Comparative Safety Profile of the Fixed-Dose C...              2019-11-22
# 7   Effectiveness of asfotase alfa for treatment o...              2024-03-09
# 8   Impact of muscular symptoms and/or pain on dis...              2023-04-14
# 9   The PARADIGHM (physicians advancing disease kn...              2021-11-22
# 10  Current Management of Patients with RPE65 Muta...              2023-03-07
#
#         pubmed_search_term
# 0   eu_pas_register_number
# 1   eu_pas_register_number
# 2   eu_pas_register_number
# 3   eu_pas_register_number
# 4   eu_pas_register_number
# 5   eu_pas_register_number
# 6   eu_pas_register_number
# 7   eu_pas_register_number
# 8   eu_pas_register_number
# 9   eu_pas_register_number
# 10  eu_pas_register_number

# %% [markdown]
# We will have to aggregate multiple entries:

# %%
articles_df = articles_df.groupby('eu_pas_register_number').agg({
    col: lambda x : '; '.join(x.astype(str))
    for col in articles_df.drop('eu_pas_register_number', axis='columns')
})

articles_df
# Out:
#                                  pubmed_id  \
# eu_pas_register_number
# 3142                              31069703
# 4270                              29748252
# 5812                              38888495
# 6942                              33964945
# 9361                              32140554
# 11384                             35766393
# 12330                             31749061
# 13514                   38459585; 37051203
# 16927                             34801015
# 31153                             36878196
#
#                                                                pubmed_url  \
# eu_pas_register_number
# 3142                            https://pubmed.ncbi.nlm.nih.gov/31069703/
# 4270                            https://pubmed.ncbi.nlm.nih.gov/29748252/
# 5812                            https://pubmed.ncbi.nlm.nih.gov/38888495/
# 6942                            https://pubmed.ncbi.nlm.nih.gov/33964945/
# 9361                            https://pubmed.ncbi.nlm.nih.gov/32140554/
# 11384                           https://pubmed.ncbi.nlm.nih.gov/35766393/
# 12330                           https://pubmed.ncbi.nlm.nih.gov/31749061/
# 13514                   https://pubmed.ncbi.nlm.nih.gov/38459585/; htt...
# 16927                           https://pubmed.ncbi.nlm.nih.gov/34801015/
# 31153                           https://pubmed.ncbi.nlm.nih.gov/36878196/
#
#                                                              pubmed_title  \
# eu_pas_register_number
# 3142                    Bismuth Concentrations in Patients Treated in ...
# 4270                    Data from the US and UK cystic fibrosis regist...
# 5812                    Long-term safety of hyaluronidase-facilitated ...
# 6942                    Longitudinal study based on a safety registry ...
# 9361                    A European, multicentre, observational, post-a...
# 11384                   Use and safety of aprotinin in routine clinica...
# 12330                   Comparative Safety Profile of the Fixed-Dose C...
# 13514                   Effectiveness of asfotase alfa for treatment o...
# 16927                   The PARADIGHM (physicians advancing disease kn...
# 31153                   Current Management of Patients with RPE65 Muta...
#
#                        pubmed_publication_date  \
# eu_pas_register_number
# 3142                                2019-05-10
# 4270                                2018-05-12
# 5812                                2024-06-18
# 6942                                2021-05-10
# 9361                                2020-03-07
# 11384                               2022-06-30
# 12330                               2019-11-22
# 13514                   2024-03-09; 2023-04-14
# 16927                               2021-11-22
# 31153                               2023-03-07
#
#                                                     pubmed_search_term
# eu_pas_register_number
# 3142                                            eu_pas_register_number
# 4270                                            eu_pas_register_number
# 5812                                            eu_pas_register_number
# 6942                                            eu_pas_register_number
# 9361                                            eu_pas_register_number
# 11384                                           eu_pas_register_number
# 12330                                           eu_pas_register_number
# 13514                   eu_pas_register_number; eu_pas_register_number
# 16927                                           eu_pas_register_number
# 31153                                           eu_pas_register_number

# %% [markdown]
# We can now save and reload this Dataframe:

# %%
articles_df.to_excel('rmp1&2_pubmed.xlsx', sheet_name='pubmed')

# %%
articles_df = pd.read_excel('rmp1&2_pubmed.xlsx', sheet_name='pubmed', index_col='eu_pas_register_number')
articles_df.head()
# Out:
#                        pubmed_id                                 pubmed_url  \
# eu_pas_register_number
# 3142                    31069703  https://pubmed.ncbi.nlm.nih.gov/31069703/
# 4270                    29748252  https://pubmed.ncbi.nlm.nih.gov/29748252/
# 5812                    38888495  https://pubmed.ncbi.nlm.nih.gov/38888495/
# 6942                    33964945  https://pubmed.ncbi.nlm.nih.gov/33964945/
# 9361                    32140554  https://pubmed.ncbi.nlm.nih.gov/32140554/
#
#                                                              pubmed_title  \
# eu_pas_register_number
# 3142                    Bismuth Concentrations in Patients Treated in ...
# 4270                    Data from the US and UK cystic fibrosis regist...
# 5812                    Long-term safety of hyaluronidase-facilitated ...
# 6942                    Longitudinal study based on a safety registry ...
# 9361                    A European, multicentre, observational, post-a...
#
#                        pubmed_publication_date      pubmed_search_term
# eu_pas_register_number
# 3142                                2019-05-10  eu_pas_register_number
# 4270                                2018-05-12  eu_pas_register_number
# 5812                                2024-06-18  eu_pas_register_number
# 6942                                2021-05-10  eu_pas_register_number
# 9361                                2020-03-07  eu_pas_register_number

# %% [markdown]
# ## Checking the references
# We will now follow  ther reference URLs and see if they references the EU PAS register number:

# %%
import re
external_df = base['references'].dropna().str.split('; ').explode().to_frame().assign(
    external_id_found=pd.NA,
    external_status_code=pd.NA
)

headers = {
    'Content-Type': 'application/json',
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:127.0) Gecko/20100101 Firefox/127.0',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,*/*;q=0.8',
    'Accept-Language': 'en-US;q=0.7,en;q=0.3',
    'Accept-Encoding': 'gzip, deflate, br, zstd',
    'Connection': 'keep-alive',
    'Priority': 'u=1'
}

external_data = []
for [id, url, *other] in tqdm(external_df.reset_index().values, total=len(external_df)):
    response = requests.get(url, headers=headers)
    found_match = None
    
    print(id, url, response.status_code, sep=' ', end="\n" if response.status_code == 200 else "\n\n")
    
    if response.status_code == 200:
        found_match = re.search(fr'\b\S*?\s*{id}', response.text, re.IGNORECASE)
        if found_match:
            found_match = found_match.group(0)
        print(found_match or pd.NA, end='\n\n')
    

    external_data.append({
        'eu_pas_register_number': id,
        'external_references': url,
        'external_id_found': found_match or pd.NA,
        'external_status_code': response.status_code,
    })

external_df = pd.DataFrame.from_records(external_data)

external_df = external_df.groupby('eu_pas_register_number').agg({
    col: lambda x : '; '.join(x.astype(str))
    for col in external_df.drop('eu_pas_register_number', axis='columns')
})

external_df
# Out:
#   0%|          | 0/36 [00:00<?, ?it/s]
# 2181 https://doi.org/10.1002/pds.3204 403
#
# 2181 https://doi.org/10.1002/pds.3371 403
#
# 2181 https://doi.org/10.1007/s00228-012-1357-8 200
# <NA>
#
# 2181 https://doi.org/10.1007/s40264-012-0013-7 200
# <NA>
#
# 2181 https://doi.org/10.1007/s40264-013-0071-5 200
# <NA>
#
# 2857 https://doi.org/10.1093/jac/dkw225 200
# <NA>
#
# 2857 https://doi.org/10.1093/jac/dkz396 200
# EUPAS2857
#
# 3142 https://doi.org/10.1007/s40264-019-00821-6 200
# EUPAS3142
#
# 3901 https://doi.org/10.1016/j.therap.2020.09.002 200
# <NA>
#
# 4270 https://doi.org/10.1136/thoraxjnl-2017-210394 200
# EUPAS4270
#
# 7708 https://doi.org/10.1159/000371798 200
# <NA>
#
# 7708 https://doi.org/10.1530/EJE-20-0325 200
# ENCEPP/SDPP/7708
#
# 7708 https://doi.org/10.3389/fendo.2022.812568 200
# <NA>
#
# 8585 https://doi.org/10.19080/JGWH.2018.09.555762 200
# <NA>
#
# 9361 https://doi.org/10.1016/S0016-5085(18)31718-9 200
# <NA>
#
# 11145 https://doi.org/10.1007/s00228-014-1697-7 200
# <NA>
#
# 13276 https://doi.org/10.1093/jcag/gwab002.214 200
# <NA>
#
# 13514 https://abstracts.eurospe.org/hrp/0094/hrp0094p1-12 200
# <NA>
#
# 13514 https://doi.org/10.1002/jbmr.4130 200
# <NA>
#
# 13514 https://doi.org/10.1186/s12891-019-2420-8 200
# 5.36606669c.3613514
#
# 13514 https://doi.org/10.1210/jendso/bvab048.530 200
# <NA>
#
# 13514 https://doi.org/10.1530/endoabs.81.P548 200
# <NA>
#
# 13616 https://doi.org/10.2147/COPD.S301624 200
# EUPAS13616
#
# 13616 https://www.rtihs.org/publications/are-you-really-dead-validation-death-and-dat… 200
# <NA>
#
# 13616 https://www.rtihs.org/publications/hospitalization-heart-failure-among-patients… 200
# <NA>
#
# 13616 https://www.rtihs.org/publications/use-aclidinium-did-not-increase-risk-death-n… 200
# <NA>
#
# 13616 https://www.rtihs.org/publications/validation-exercise-identifying-hospitalizat… 200
# <NA>
#
# 15411 https://doi.org/10.1136/bjophthalmol-2018-312284 200
# <NA>
#
# 17386 https://doi.org/10.1038/s41598-019-57397-5 200
# EUPAS 17386
#
# 17386 https://www.rtihs.org/sites/default/files/29672%20Rebirdosa%202019%20Utilizatio… 200
# <NA>
#
# 20668 https://onlinelibrary.wiley.com/toc/10990496/2018/53/S2 403
#
# 20720 https://doi.org/10.1002/pds.5319 403
#
# 20720 https://doi.org/10.1002/pds.5348 403
#
# 20720 https://www.rtihs.org/sites/default/files/29674%20Gutierrez%202019%20Challenges… 200
# <NA>
#
# 20720 https://www.rtihs.org/sites/default/files/30541%20Gutierrez%202020%20A%20multin… 200
# <NA>
#
# 21574 https://doi.org/10.1002/pds.5432 403
#                                                       external_references  \
# eu_pas_register_number
# 2181                    https://doi.org/10.1002/pds.3204; https://doi....
# 2857                    https://doi.org/10.1093/jac/dkw225; https://do...
# 3142                           https://doi.org/10.1007/s40264-019-00821-6
# 3901                         https://doi.org/10.1016/j.therap.2020.09.002
# 4270                        https://doi.org/10.1136/thoraxjnl-2017-210394
# 7708                    https://doi.org/10.1159/000371798; https://doi...
# 8585                         https://doi.org/10.19080/JGWH.2018.09.555762
# 9361                        https://doi.org/10.1016/S0016-5085(18)31718-9
# 11145                           https://doi.org/10.1007/s00228-014-1697-7
# 13276                            https://doi.org/10.1093/jcag/gwab002.214
# 13514                   https://abstracts.eurospe.org/hrp/0094/hrp0094...
# 13616                   https://doi.org/10.2147/COPD.S301624; https://...
# 15411                    https://doi.org/10.1136/bjophthalmol-2018-312284
# 17386                   https://doi.org/10.1038/s41598-019-57397-5; ht...
# 20668                   https://onlinelibrary.wiley.com/toc/10990496/2...
# 20720                   https://doi.org/10.1002/pds.5319; https://doi....
# 21574                                    https://doi.org/10.1002/pds.5432
#
#                                                   external_id_found  \
# eu_pas_register_number
# 2181                                   <NA>; <NA>; <NA>; <NA>; <NA>
# 2857                                                <NA>; EUPAS2857
# 3142                                                      EUPAS3142
# 3901                                                           <NA>
# 4270                                                      EUPAS4270
# 7708                                   <NA>; ENCEPP/SDPP/7708; <NA>
# 8585                                                           <NA>
# 9361                                                           <NA>
# 11145                                                          <NA>
# 13276                                                          <NA>
# 13514                   <NA>; <NA>; 5.36606669c.3613514; <NA>; <NA>
# 13616                            EUPAS13616; <NA>; <NA>; <NA>; <NA>
# 15411                                                          <NA>
# 17386                                             EUPAS 17386; <NA>
# 20668                                                          <NA>
# 20720                                        <NA>; <NA>; <NA>; <NA>
# 21574                                                          <NA>
#
#                            external_status_code
# eu_pas_register_number
# 2181                    403; 403; 200; 200; 200
# 2857                                   200; 200
# 3142                                        200
# 3901                                        200
# 4270                                        200
# 7708                              200; 200; 200
# 8585                                        200
# 9361                                        200
# 11145                                       200
# 13276                                       200
# 13514                   200; 200; 200; 200; 200
# 13616                   200; 200; 200; 200; 200
# 15411                                       200
# 17386                                  200; 200
# 20668                                       403
# 20720                        403; 403; 200; 200
# 21574                                       403

# %% [markdown]
# We can now save and reload this Dataframe:

# %%
external_df.to_excel('rmp1&2_external.xlsx', sheet_name='external')

# %%
external_df = pd.read_excel('rmp1&2_external.xlsx', sheet_name='external', index_col='eu_pas_register_number')
external_df.head()
# Out:
#                                                       external_references  \
# eu_pas_register_number
# 2181                    https://doi.org/10.1002/pds.3204; https://doi....
# 2857                    https://doi.org/10.1093/jac/dkw225; https://do...
# 3142                           https://doi.org/10.1007/s40264-019-00821-6
# 3901                         https://doi.org/10.1016/j.therap.2020.09.002
# 4270                        https://doi.org/10.1136/thoraxjnl-2017-210394
#
#                                    external_id_found     external_status_code
# eu_pas_register_number
# 2181                    <NA>; <NA>; <NA>; <NA>; <NA>  403; 403; 200; 200; 200
# 2857                                 <NA>; EUPAS2857                 200; 200
# 3142                                       EUPAS3142                      200
# 3901                                             NaN                      200
# 4270                                       EUPAS4270                      200

# %% [markdown]
# ## Putting all data together
# We will now merge the nct data, the pubmed data and the external references data with the original Dataframe:

# %%
references_df = base.merge(
    nct_df,
    how='left', 
    left_index=True,
    right_index=True
).merge(
    articles_df,
    how='left', 
    left_index=True,
    right_index=True
).merge(
    external_df,
    how='left', 
    left_index=True,
    right_index=True
)

references_df.head()
# Out:
#                                                                     title  \
# eu_pas_register_number
# 2165                    Post-Authorisation Safety Study of Esbriet® (P...
# 2181                    Study of Acute Liver Transplant: A study of NS...
# 2196                    Prospective controlled cohort study on the saf...
# 2857                    A Multicenter Cohort Study of the Short and Lo...
# 3142                    A Safety and Pharmacokinetic study in Real-lif...
#
#                                                                  url  \
# eu_pas_register_number
# 2165                    https://catalogues.ema.europa.eu/study/23388
# 2181                    https://catalogues.ema.europa.eu/study/40864
# 2196                    https://catalogues.ema.europa.eu/study/41500
# 2857                    https://catalogues.ema.europa.eu/study/35221
# 3142                    https://catalogues.ema.europa.eu/study/47210
#
#                        regulatory_procedure_number  \
# eu_pas_register_number
# 2165                                           NaN
# 2181                                           NaN
# 2196                                           NaN
# 2857                                           NaN
# 3142                                           NaN
#
#                                                                references  \
# eu_pas_register_number
# 2165                                                                  NaN
# 2181                    https://doi.org/10.1002/pds.3204; https://doi....
# 2196                                                                  NaN
# 2857                    https://doi.org/10.1093/jac/dkw225; https://do...
# 3142                           https://doi.org/10.1007/s40264-019-00821-6
#
#                          acronym  nct_total_count  \
# eu_pas_register_number
# 2165                    PASSPORT              5.0
# 2181                      SALT-I              0.0
# 2196                      PRO-E2              1.0
# 2857                       MYCOS              1.0
# 3142                         NaN              0.0
#
#                                                                   nct_url  \
# eu_pas_register_number
# 2165                    https://www.clinicaltrials.gov/study/NCT062742...
# 2181                                                                  NaN
# 2196                     https://www.clinicaltrials.gov/study/NCT01650168
# 2857                     https://www.clinicaltrials.gov/study/NCT01686607
# 3142                                                                  NaN
#
#                                                                    nct_id  \
# eu_pas_register_number
# 2165                    NCT06274294; NCT04716023; NCT03068468; NCT0397...
# 2181                                                                  NaN
# 2196                                                          NCT01650168
# 2857                                                          NCT01686607
# 3142                                                                  NaN
#
#                                                                 nct_state  \
# eu_pas_register_number
# 2165                    NOT_YET_RECRUITING; UNKNOWN; TERMINATED; COMPL...
# 2181                                                                  NaN
# 2196                                                            COMPLETED
# 2857                                                            COMPLETED
# 3142                                                                  NaN
#
#                                                          nct_first_posted  \
# eu_pas_register_number
# 2165                    2024-02-23; 2021-01-20; 2017-03-01; 2019-06-07...
# 2181                                                                  NaN
# 2196                                                           2012-07-26
# 2857                                                           2012-09-18
# 3142                                                                  NaN
#
#                         ... nct_status_code nct_search_term pubmed_id  \
# eu_pas_register_number  ...
# 2165                    ...             200         acronym       NaN
# 2181                    ...             200             NaN       NaN
# 2196                    ...             200           title       NaN
# 2857                    ...             200           title       NaN
# 3142                    ...             200             NaN  31069703
#
#                                                        pubmed_url  \
# eu_pas_register_number
# 2165                                                          NaN
# 2181                                                          NaN
# 2196                                                          NaN
# 2857                                                          NaN
# 3142                    https://pubmed.ncbi.nlm.nih.gov/31069703/
#
#                                                              pubmed_title  \
# eu_pas_register_number
# 2165                                                                  NaN
# 2181                                                                  NaN
# 2196                                                                  NaN
# 2857                                                                  NaN
# 3142                    Bismuth Concentrations in Patients Treated in ...
#
#                        pubmed_publication_date      pubmed_search_term  \
# eu_pas_register_number
# 2165                                       NaN                     NaN
# 2181                                       NaN                     NaN
# 2196                                       NaN                     NaN
# 2857                                       NaN                     NaN
# 3142                                2019-05-10  eu_pas_register_number
#
#                                                       external_references  \
# eu_pas_register_number
# 2165                                                                  NaN
# 2181                    https://doi.org/10.1002/pds.3204; https://doi....
# 2196                                                                  NaN
# 2857                    https://doi.org/10.1093/jac/dkw225; https://do...
# 3142                           https://doi.org/10.1007/s40264-019-00821-6
#
#                                    external_id_found     external_status_code
# eu_pas_register_number
# 2165                                             NaN                      NaN
# 2181                    <NA>; <NA>; <NA>; <NA>; <NA>  403; 403; 200; 200; 200
# 2196                                             NaN                      NaN
# 2857                                 <NA>; EUPAS2857                 200; 200
# 3142                                       EUPAS3142                      200
#
# [5 rows x 24 columns]

# %% [markdown]
# We can now save and reload the combined results:

# %%
references_df.to_excel('rmp1&2_all_references.xlsx', sheet_name='references')

# %%
references_df = pd.read_excel('rmp1&2_all_references.xlsx', sheet_name='references', index_col='eu_pas_register_number')
references_df.head()
# Out:
#                                                                     title  \
# eu_pas_register_number
# 2165                    Post-Authorisation Safety Study of Esbriet® (P...
# 2181                    Study of Acute Liver Transplant: A study of NS...
# 2196                    Prospective controlled cohort study on the saf...
# 2857                    A Multicenter Cohort Study of the Short and Lo...
# 3142                    A Safety and Pharmacokinetic study in Real-lif...
#
#                                                                  url  \
# eu_pas_register_number
# 2165                    https://catalogues.ema.europa.eu/study/23388
# 2181                    https://catalogues.ema.europa.eu/study/40864
# 2196                    https://catalogues.ema.europa.eu/study/41500
# 2857                    https://catalogues.ema.europa.eu/study/35221
# 3142                    https://catalogues.ema.europa.eu/study/47210
#
#                        regulatory_procedure_number  \
# eu_pas_register_number
# 2165                                           NaN
# 2181                                           NaN
# 2196                                           NaN
# 2857                                           NaN
# 3142                                           NaN
#
#                                                                references  \
# eu_pas_register_number
# 2165                                                                  NaN
# 2181                    https://doi.org/10.1002/pds.3204; https://doi....
# 2196                                                                  NaN
# 2857                    https://doi.org/10.1093/jac/dkw225; https://do...
# 3142                           https://doi.org/10.1007/s40264-019-00821-6
#
#                          acronym  nct_total_count  \
# eu_pas_register_number
# 2165                    PASSPORT              5.0
# 2181                      SALT-I              0.0
# 2196                      PRO-E2              1.0
# 2857                       MYCOS              1.0
# 3142                         NaN              0.0
#
#                                                                   nct_url  \
# eu_pas_register_number
# 2165                    https://www.clinicaltrials.gov/study/NCT062742...
# 2181                                                                  NaN
# 2196                     https://www.clinicaltrials.gov/study/NCT01650168
# 2857                     https://www.clinicaltrials.gov/study/NCT01686607
# 3142                                                                  NaN
#
#                                                                    nct_id  \
# eu_pas_register_number
# 2165                    NCT06274294; NCT04716023; NCT03068468; NCT0397...
# 2181                                                                  NaN
# 2196                                                          NCT01650168
# 2857                                                          NCT01686607
# 3142                                                                  NaN
#
#                                                                 nct_state  \
# eu_pas_register_number
# 2165                    NOT_YET_RECRUITING; UNKNOWN; TERMINATED; COMPL...
# 2181                                                                  NaN
# 2196                                                            COMPLETED
# 2857                                                            COMPLETED
# 3142                                                                  NaN
#
#                                                          nct_first_posted  \
# eu_pas_register_number
# 2165                    2024-02-23; 2021-01-20; 2017-03-01; 2019-06-07...
# 2181                                                                  NaN
# 2196                                                           2012-07-26
# 2857                                                           2012-09-18
# 3142                                                                  NaN
#
#                         ... nct_status_code nct_search_term pubmed_id  \
# eu_pas_register_number  ...
# 2165                    ...             200         acronym       NaN
# 2181                    ...             200             NaN       NaN
# 2196                    ...             200           title       NaN
# 2857                    ...             200           title       NaN
# 3142                    ...             200             NaN  31069703
#
#                                                        pubmed_url  \
# eu_pas_register_number
# 2165                                                          NaN
# 2181                                                          NaN
# 2196                                                          NaN
# 2857                                                          NaN
# 3142                    https://pubmed.ncbi.nlm.nih.gov/31069703/
#
#                                                              pubmed_title  \
# eu_pas_register_number
# 2165                                                                  NaN
# 2181                                                                  NaN
# 2196                                                                  NaN
# 2857                                                                  NaN
# 3142                    Bismuth Concentrations in Patients Treated in ...
#
#                        pubmed_publication_date      pubmed_search_term  \
# eu_pas_register_number
# 2165                                       NaN                     NaN
# 2181                                       NaN                     NaN
# 2196                                       NaN                     NaN
# 2857                                       NaN                     NaN
# 3142                                2019-05-10  eu_pas_register_number
#
#                                                       external_references  \
# eu_pas_register_number
# 2165                                                                  NaN
# 2181                    https://doi.org/10.1002/pds.3204; https://doi....
# 2196                                                                  NaN
# 2857                    https://doi.org/10.1093/jac/dkw225; https://do...
# 3142                           https://doi.org/10.1007/s40264-019-00821-6
#
#                                    external_id_found     external_status_code
# eu_pas_register_number
# 2165                                             NaN                      NaN
# 2181                    <NA>; <NA>; <NA>; <NA>; <NA>  403; 403; 200; 200; 200
# 2196                                             NaN                      NaN
# 2857                                 <NA>; EUPAS2857                 200; 200
# 3142                                       EUPAS3142                      200
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Experiments

# %% [markdown]
# Single NCT ID Query:

# %%
import json

nct_id = 'NCT03774914'
response = requests.get(f"https://clinicaltrials.gov/api/v2/studies/{nct_id}?format=json&markupFormat=markdown")

if response.status_code == 200:
    print(json.dumps(response.json(), indent=4))
# Out:
# {
#     "protocolSection": {
#         "identificationModule": {
#             "nctId": "NCT03774914",
#             "orgStudyIdInfo": {
#                 "id": "OBS13436"
#             },
#             "secondaryIdInfos": [
#                 {
#                     "id": "EU PAS - cat 3"
#                 }
#             ],
#             "organization": {
#                 "fullName": "Sanofi",
#                 "class": "INDUSTRY"
#             },
#             "briefTitle": "LEMTRADA Pregnancy Registry in Multiple Sclerosis",
#             "officialTitle": "International LEMTRADA Pregnancy Exposure Cohort in Multiple Sclerosis"
#         },
#         "statusModule": {
#             "statusVerifiedDate": "2022-04-21",
#             "overallStatus": "TERMINATED",
#             "whyStopped": "The sponsor stopped the study due to low recruitment with no safety concerns",
#             "expandedAccessInfo": {
#                 "hasExpandedAccess": false
#             },
#             "startDateStruct": {
#                 "date": "2015-09-01",
#                 "type": "ACTUAL"
#             },
#             "primaryCompletionDateStruct": {
#                 "date": "2021-11-22",
#                 "type": "ACTUAL"
#             },
#             "completionDateStruct": {
#                 "date": "2021-11-22",
#                 "type": "ACTUAL"
#             },
#             "studyFirstSubmitDate": "2018-12-11",
#             "studyFirstSubmitQcDate": "2018-12-11",
#             "studyFirstPostDateStruct": {
#                 "date": "2018-12-13",
#                 "type": "ACTUAL"
#             },
#             "lastUpdateSubmitDate": "2022-04-21",
#             "lastUpdatePostDateStruct": {
#                 "date": "2022-04-25",
#                 "type": "ACTUAL"
#             }
#         },
#         "sponsorCollaboratorsModule": {
#             "responsibleParty": {
#                 "type": "SPONSOR"
#             },
#             "leadSponsor": {
#                 "name": "Genzyme, a Sanofi Company",
#                 "class": "INDUSTRY"
#             }
#         },
#         "oversightModule": {
#             "oversightHasDmc": false,
#             "isFdaRegulatedDrug": false,
#             "isFdaRegulatedDevice": false,
#             "isUsExport": false
#         },
#         "descriptionModule": {
#             "briefSummary": "Primary Objective:\n\nThe primary goal of this registry is to assess the risk of spontaneous abortion in prospective enrolled women exposed to LEMTRADA for multiple sclerosis.\n\nSecondary Objective:\n\nThe secondary goals of this registry is to assess maternal, fetal and infant outcome in women with multiple sclerosis, exposed to LEMTRADA.",
#             "detailedDescription": "From enrollment during pregnancy up to 1 year after delivery for infant follow-up (maximum approximatively 20 months)"
#         },
#         "conditionsModule": {
#             "conditions": [
#                 "Multiple Sclerosis"
#             ]
#         },
#         "designModule": {
#             "studyType": "OBSERVATIONAL",
#             "patientRegistry": true,
#             "targetDuration": "20 Months",
#             "designInfo": {
#                 "observationalModel": "COHORT",
#                 "timePerspective": "PROSPECTIVE"
#             },
#             "enrollmentInfo": {
#                 "count": 42,
#                 "type": "ACTUAL"
#             }
#         },
#         "armsInterventionsModule": {
#             "armGroups": [
#                 {
#                     "label": "Lemtrada",
#                     "description": "Pregnant women exposed to LEMTRADA which is administered by IV infusion for 5 consecutive days, then for 3 consecutive days, 12 months after the first/previous treatment course",
#                     "interventionNames": [
#                         "Drug: Alemtuzumab (GZ402673)"
#                     ]
#                 }
#             ],
#             "interventions": [
#                 {
#                     "type": "DRUG",
#                     "name": "Alemtuzumab (GZ402673)",
#                     "description": "Pharmaceutical form:Concentrate for solution for infusion Route of administration: Intravenous infusion",
#                     "armGroupLabels": [
#                         "Lemtrada"
#                     ],
#                     "otherNames": [
#                         "Lemtrada"
#                     ]
#                 }
#             ]
#         },
#         "outcomesModule": {
#             "primaryOutcomes": [
#                 {
#                     "measure": "Spontaneous abortions (\u226420 weeks gestation)",
#                     "description": "Number and rate of spontaneous abortions on pregnant women prospectively enrolled (pregnancy outcome unknown at time of enrollment)",
#                     "timeFrame": "32 weeks gestation"
#                 }
#             ],
#             "secondaryOutcomes": [
#                 {
#                     "measure": "Major congenital malformations",
#                     "description": "Numbers and rates of major congenital malformations on pregnant women prospectively enrolled (pregnancy outcome unknown at time of enrollment)",
#                     "timeFrame": "From birth to 1 year after delivery"
#                 },
#                 {
#                     "measure": "Minor congenital malformations",
#                     "description": "Numbers and rates of minor congenital malformations on pregnant women prospectively enrolled (pregnancy outcome unknown at time of enrollment)",
#                     "timeFrame": "From birth to 1 year after delivery"
#                 },
#                 {
#                     "measure": "Stillbirth (any non-deliberate foetal death at >20 weeks gestation)",
#                     "description": "Numbers and rates of stillbirth, on pregnant women prospectively enrolled (pregnancy outcome unknown at time of enrollment)",
#                     "timeFrame": "26-32 weeks' gestation to within 6 weeks after the end of the pregnancy"
#                 },
#                 {
#                     "measure": "Full-term live birth i.e. infants born maturely (\u226537 gestation weeks)",
#                     "description": "Numbers and rates of full-term live birth on pregnant women prospectively enrolled (pregnancy outcome unknown at time of enrollment)",
#                     "timeFrame": "Within 6 weeks after the end of the pregnancy"
#                 },
#                 {
#                     "measure": "Preterm birth i.e. infants born prematurely i.e., live-born infant i.e., (pre-term <37 weeks)",
#                     "description": "Numbers and rates of pre-term birth on pregnant women prospectively enrolled (pregnancy outcome unknown at time of enrollment)",
#                     "timeFrame": "26-32 weeks' gestation to within 6 weeks after the end of the pregnancy"
#                 },
#                 {
#                     "measure": "Elective terminations i.e. any induced or voluntary fetal loss",
#                     "description": "Numbers and rates of elective terminations on pregnant women prospectively enrolled (pregnancy outcome unknown at time of enrollment)",
#                     "timeFrame": "16-20 weeks' gestation"
#                 },
#                 {
#                     "measure": "Small for gestational age at birth i.e. birth size (weight, length, or head circumference) \u226410th percentile for gender and gestational age",
#                     "description": "Numbers and rates of small for gestational age on pregnant women prospectively enrolled (pregnancy outcome unknown at time of enrollment)",
#                     "timeFrame": "Within 6 weeks after the end of the pregnancy"
#                 },
#                 {
#                     "measure": "Any other adverse pregnancy outcomes",
#                     "description": "Numbers of adverse events",
#                     "timeFrame": "Baseline to week 40"
#                 },
#                 {
#                     "measure": "Infant postnatal growth (up to the first year of life)",
#                     "description": "Numbers and rates of infants with postnatal size (weight, length or head circumference) less than or equal to the 10th percentile for sex and age using National Center for Health Statistics (NCHS) pediatric growth curves, and adjusted postnatal age for premature infants.",
#                     "timeFrame": "1 year after delivery"
#                 },
#                 {
#                     "measure": "Infant development impairment (up to the first year of life)",
#                     "description": "Numbers and rates of infants with development impairment",
#                     "timeFrame": "1 year after delivery"
#                 }
#             ]
#         },
#         "eligibilityModule": {
#             "eligibilityCriteria": "Inclusion criteria :\n\n* Women with Multiple Sclerosis who were or became pregnant within the period of time between the first infusion of a course of treatment with LEMTRADA to 4 months after their last infusion for that course.\n* Women able and willing to provide informed consent for study participation and the requirement of the study. Informed consent will be obtained at the time of enrollment in accordance with local regulatory requirements.\n\nExclusion criteria:\n\n- Previous enrollment in this study for a previous pregnancy.\n\nThe above information is not intended to contain all considerations relevant to a patient's potential participation in a clinical trial.",
#             "healthyVolunteers": false,
#             "sex": "FEMALE",
#             "minimumAge": "18 Years",
#             "maximumAge": "55 Years",
#             "stdAges": [
#                 "ADULT"
#             ],
#             "studyPopulation": "Women with Multiple Sclerosis who were or became pregnant within the period of time between the first infusion of a course of treatment with LEMTRADA to 4 months after their last infusion for that course.",
#             "samplingMethod": "NON_PROBABILITY_SAMPLE"
#         },
#         "contactsLocationsModule": {
#             "overallOfficials": [
#                 {
#                     "name": "Clinical Sciences & Operations",
#                     "affiliation": "Sanofi",
#                     "role": "STUDY_DIRECTOR"
#                 }
#             ],
#             "locations": [
#                 {
#                     "facility": "Investigational Site Number :840999",
#                     "city": "New York",
#                     "state": "New York",
#                     "zip": "00000",
#                     "country": "United States",
#                     "geoPoint": {
#                         "lat": 40.71427,
#                         "lon": -74.00597
#                     }
#                 },
#                 {
#                     "facility": "Investigational Site Number :036001",
#                     "city": "Box Hill",
#                     "state": "Victoria",
#                     "zip": "3128",
#                     "country": "Australia",
#                     "geoPoint": {
#                         "lat": -37.81887,
#                         "lon": 145.12545
#                     }
#                 },
#                 {
#                     "facility": "Investigational Site Number :040-001",
#                     "city": "Linz",
#                     "country": "Austria",
#                     "geoPoint": {
#                         "lat": 48.30639,
#                         "lon": 14.28611
#                     }
#                 },
#                 {
#                     "facility": "Investigational Site Number :56",
#                     "city": "Charleroi",
#                     "zip": "6000",
#                     "country": "Belgium",
#                     "geoPoint": {
#                         "lat": 50.41136,
#                         "lon": 4.44448
#                     }
#                 },
#                 {
#                     "facility": "Investigational Site Number :124999",
#                     "city": "Canada",
#                     "country": "Canada"
#                 },
#                 {
#                     "facility": "Investigational Site Number :208001",
#                     "city": "Aarhus C",
#                     "zip": "8000",
#                     "country": "Denmark",
#                     "geoPoint": {
#                         "lat": 56.15674,
#                         "lon": 10.21076
#                     }
#                 },
#                 {
#                     "facility": "Investigational Site Number :276001",
#                     "city": "Bochum",
#                     "zip": "44791",
#                     "country": "Germany",
#                     "geoPoint": {
#                         "lat": 51.48165,
#                         "lon": 7.21648
#                     }
#                 },
#                 {
#                     "facility": "Investigational Site Number :380001",
#                     "city": "Gallarate (VA)",
#                     "zip": "21013",
#                     "country": "Italy"
#                 },
#                 {
#                     "facility": "Investigational Site Number :528999",
#                     "city": "Netherlands",
#                     "country": "Netherlands"
#                 },
#                 {
#                     "facility": "Investigational Site Number :724999",
#                     "city": "Spain",
#                     "country": "Spain"
#                 },
#                 {
#                     "facility": "Investigational Site Number :752001",
#                     "city": "G\u00f6teborg",
#                     "zip": "41345",
#                     "country": "Sweden",
#                     "geoPoint": {
#                         "lat": 57.70716,
#                         "lon": 11.96679
#                     }
#                 },
#                 {
#                     "facility": "Investigational Site Number :756001",
#                     "city": "Z\u00fcrich",
#                     "zip": "8091",
#                     "country": "Switzerland",
#                     "geoPoint": {
#                         "lat": 47.36667,
#                         "lon": 8.54999
#                     }
#                 },
#                 {
#                     "facility": "Investigational Site Number :826-001",
#                     "city": "Salford",
#                     "zip": "M6 8HD",
#                     "country": "United Kingdom",
#                     "geoPoint": {
#                         "lat": 53.48771,
#                         "lon": -2.29042
#                     }
#                 }
#             ]
#         },
#         "ipdSharingStatementModule": {
#             "ipdSharing": "YES",
#             "description": "Qualified researchers may request access to patient level data and related study documents including the clinical study report, study protocol with any amendments, blank case report form, statistical analysis plan, and dataset specifications. Patient level data will be anonymized and study documents will be redacted to protect the privacy of trial participants. Further details on Sanofi's data sharing criteria, eligible studies, and process for requesting access can be found at: https://vivli.org"
#         }
#     },
#     "derivedSection": {
#         "miscInfoModule": {
#             "versionHolder": "2024-06-28"
#         },
#         "conditionBrowseModule": {
#             "meshes": [
#                 {
#                     "id": "D000009103",
#                     "term": "Multiple Sclerosis"
#                 },
#                 {
#                     "id": "D000012598",
#                     "term": "Sclerosis"
#                 }
#             ],
#             "ancestors": [
#                 {
#                     "id": "D000010335",
#                     "term": "Pathologic Processes"
#                 },
#                 {
#                     "id": "D000020278",
#                     "term": "Demyelinating Autoimmune Diseases, CNS"
#                 },
#                 {
#                     "id": "D000020274",
#                     "term": "Autoimmune Diseases of the Nervous System"
#                 },
#                 {
#                     "id": "D000009422",
#                     "term": "Nervous System Diseases"
#                 },
#                 {
#                     "id": "D000003711",
#                     "term": "Demyelinating Diseases"
#                 },
#                 {
#                     "id": "D000001327",
#                     "term": "Autoimmune Diseases"
#                 },
#                 {
#                     "id": "D000007154",
#                     "term": "Immune System Diseases"
#                 }
#             ],
#             "browseLeaves": [
#                 {
#                     "id": "M12060",
#                     "name": "Multiple Sclerosis",
#                     "asFound": "Multiple Sclerosis",
#                     "relevance": "HIGH"
#                 },
#                 {
#                     "id": "M15415",
#                     "name": "Sclerosis",
#                     "asFound": "Sclerosis",
#                     "relevance": "HIGH"
#                 },
#                 {
#                     "id": "M4629",
#                     "name": "Autoimmune Diseases",
#                     "relevance": "LOW"
#                 },
#                 {
#                     "id": "M22098",
#                     "name": "Demyelinating Autoimmune Diseases, CNS",
#                     "relevance": "LOW"
#                 },
#                 {
#                     "id": "M22094",
#                     "name": "Autoimmune Diseases of the Nervous System",
#                     "relevance": "LOW"
#                 },
#                 {
#                     "id": "M6909",
#                     "name": "Demyelinating Diseases",
#                     "relevance": "LOW"
#                 },
#                 {
#                     "id": "M10200",
#                     "name": "Immune System Diseases",
#                     "relevance": "LOW"
#                 }
#             ],
#             "browseBranches": [
#                 {
#                     "abbrev": "BC10",
#                     "name": "Nervous System Diseases"
#                 },
#                 {
#                     "abbrev": "BC20",
#                     "name": "Immune System Diseases"
#                 },
#                 {
#                     "abbrev": "All",
#                     "name": "All Conditions"
#                 },
#                 {
#                     "abbrev": "BC23",
#                     "name": "Symptoms and General Pathology"
#                 }
#             ]
#         },
#         "interventionBrowseModule": {
#             "meshes": [
#                 {
#                     "id": "D000074323",
#                     "term": "Alemtuzumab"
#                 }
#             ],
#             "ancestors": [
#                 {
#                     "id": "D000074322",
#                     "term": "Antineoplastic Agents, Immunological"
#                 },
#                 {
#                     "id": "D000000970",
#                     "term": "Antineoplastic Agents"
#                 }
#             ],
#             "browseLeaves": [
#                 {
#                     "id": "M21860",
#                     "name": "Pharmaceutical Solutions",
#                     "relevance": "LOW"
#                 },
#                 {
#                     "id": "M1347",
#                     "name": "Alemtuzumab",
#                     "asFound": "Run-",
#                     "relevance": "HIGH"
#                 },
#                 {
#                     "id": "M1346",
#                     "name": "Antineoplastic Agents, Immunological",
#                     "relevance": "LOW"
#                 }
#             ],
#             "browseBranches": [
#                 {
#                     "abbrev": "PhSol",
#                     "name": "Pharmaceutical Solutions"
#                 },
#                 {
#                     "abbrev": "All",
#                     "name": "All Drugs and Chemicals"
#                 },
#                 {
#                     "abbrev": "ANeo",
#                     "name": "Antineoplastic Agents"
#                 }
#             ]
#         }
#     },
#     "hasResults": false
# }

# %% [markdown]
# Find all Pubmed entries with the term "eu pas" or "eupas" or "eupas" followed by extra text:

# %%
pubmed = PubMed(tool="EmaRwdSearcher", email="pedram.ramezani@charite.de")

# NOTE: Old identifier? "ENCEPP/*/*"

search_term = 'eupas OR "eu pas" OR eupas*'
results = pubmed.query(search_term, max_results=1000)
article_list = []
article_info = []

for article in results:
    article_dict = article.toDict()
    article_list.append(article_dict)


for article in article_list:
    # Sometimes article['pubmed_id'] contains list separated with comma - take first pubmedId in that list - thats article pubmedId
    pubmedId = article['pubmed_id'].partition('\n')[0]
    
    article_info.append({
        'pubmed_id': pubmedId,
        'pubmed_url': f'https://pubmed.ncbi.nlm.nih.gov/{pubmedId}/',
        'title': article['title'],
        'publication_date': article['publication_date']
    })

all_ema_rwd_articles_df = pd.DataFrame.from_dict(article_info)

all_ema_rwd_articles_df
# Out:
# dict_keys(['pubmed_id', 'title', 'abstract', 'keywords', 'journal', 'publication_date', 'authors', 'methods', 'conclusions', 'results', 'copyrights', 'doi', 'xml'])
#   pubmed_id                                              title  \
# 0  38888495  Long-term safety of hyaluronidase-facilitated ...
#
#                              doi publication_date
# 0  10.1080/1750743X.2024.2354091       2024-06-18

# %%
analysis_df = exported.assign(
    acronym=lambda x : x['title'].str.extract(r'\((?P<acronym>[^\(\)]+)\)\s*$'),
    has_result_tables = lambda x : x['result_tables_name'].notna(),
    has_result_documents = lambda x : x['result_document_name'].notna(),
    has_result=lambda x : x['has_result_tables'] | x['has_result_documents'],
    has_other=lambda x : x['other_documents_name'].notna(),
)[exported['risk_management_plan'].isin([
    'EU RMP category 1 (imposed as condition of marketing authorisation)',
    'EU RMP category 2 (specific obligation of marketing authorisation)'
])].filter(regex='title|references|has_result$|has_other|^url$')

# Filter all studies without result documents, but with references
analysis_df = analysis_df[~analysis_df['has_result'] & analysis_df['references'].notna()]

analysis_df.loc[:, 'references'] = analysis_df['references'].str.split('; ')

analysis_df = analysis_df.explode('references').assign(
    result_in_reference=pd.NA
)

analysis_df
# Out:
#                                                                     title  \
# eu_pas_register_number
# 2181                    Study of Acute Liver Transplant: A study of NS...
# 2181                    Study of Acute Liver Transplant: A study of NS...
# 2181                    Study of Acute Liver Transplant: A study of NS...
# 2181                    Study of Acute Liver Transplant: A study of NS...
# 2181                    Study of Acute Liver Transplant: A study of NS...
# 8585                    Safety and Incidence of Side Effects in a Coho...
# 13276                   An observational disease and clinical outcomes...
# 13514                   AN OBSERVATIONAL, LONGITUDINAL, PROSPECTIVE, L...
# 13514                   AN OBSERVATIONAL, LONGITUDINAL, PROSPECTIVE, L...
# 13514                   AN OBSERVATIONAL, LONGITUDINAL, PROSPECTIVE, L...
# 13514                   AN OBSERVATIONAL, LONGITUDINAL, PROSPECTIVE, L...
# 13514                   AN OBSERVATIONAL, LONGITUDINAL, PROSPECTIVE, L...
# 13616                   Aclidinium Bromide Post-Authorisation Safety S...
# 13616                   Aclidinium Bromide Post-Authorisation Safety S...
# 13616                   Aclidinium Bromide Post-Authorisation Safety S...
# 13616                   Aclidinium Bromide Post-Authorisation Safety S...
# 13616                   Aclidinium Bromide Post-Authorisation Safety S...
#
#                                                                  url  \
# eu_pas_register_number
# 2181                    https://catalogues.ema.europa.eu/study/40864
# 2181                    https://catalogues.ema.europa.eu/study/40864
# 2181                    https://catalogues.ema.europa.eu/study/40864
# 2181                    https://catalogues.ema.europa.eu/study/40864
# 2181                    https://catalogues.ema.europa.eu/study/40864
# 8585                    https://catalogues.ema.europa.eu/study/41123
# 13276                   https://catalogues.ema.europa.eu/study/47904
# 13514                   https://catalogues.ema.europa.eu/study/47907
# 13514                   https://catalogues.ema.europa.eu/study/47907
# 13514                   https://catalogues.ema.europa.eu/study/47907
# 13514                   https://catalogues.ema.europa.eu/study/47907
# 13514                   https://catalogues.ema.europa.eu/study/47907
# 13616                   https://catalogues.ema.europa.eu/study/42316
# 13616                   https://catalogues.ema.europa.eu/study/42316
# 13616                   https://catalogues.ema.europa.eu/study/42316
# 13616                   https://catalogues.ema.europa.eu/study/42316
# 13616                   https://catalogues.ema.europa.eu/study/42316
#
#                                                                references  \
# eu_pas_register_number
# 2181                                     https://doi.org/10.1002/pds.3204
# 2181                                     https://doi.org/10.1002/pds.3371
# 2181                            https://doi.org/10.1007/s00228-012-1357-8
# 2181                            https://doi.org/10.1007/s40264-012-0013-7
# 2181                            https://doi.org/10.1007/s40264-013-0071-5
# 8585                         https://doi.org/10.19080/JGWH.2018.09.555762
# 13276                            https://doi.org/10.1093/jcag/gwab002.214
# 13514                   https://abstracts.eurospe.org/hrp/0094/hrp0094...
# 13514                                   https://doi.org/10.1002/jbmr.4130
# 13514                           https://doi.org/10.1186/s12891-019-2420-8
# 13514                          https://doi.org/10.1210/jendso/bvab048.530
# 13514                             https://doi.org/10.1530/endoabs.81.P548
# 13616                                https://doi.org/10.2147/COPD.S301624
# 13616                   https://www.rtihs.org/publications/are-you-rea...
# 13616                   https://www.rtihs.org/publications/hospitaliza...
# 13616                   https://www.rtihs.org/publications/use-aclidin...
# 13616                   https://www.rtihs.org/publications/validation-...
#
#                         has_result  has_other result_in_reference
# eu_pas_register_number
# 2181                         False      False                <NA>
# 2181                         False      False                <NA>
# 2181                         False      False                <NA>
# 2181                         False      False                <NA>
# 2181                         False      False                <NA>
# 8585                         False      False                <NA>
# 13276                        False      False                <NA>
# 13514                        False      False                <NA>
# 13514                        False      False                <NA>
# 13514                        False      False                <NA>
# 13514                        False      False                <NA>
# 13514                        False      False                <NA>
# 13616                        False      False                <NA>
# 13616                        False      False                <NA>
# 13616                        False      False                <NA>
# 13616                        False      False                <NA>
# 13616                        False      False                <NA>

# %%
analysis_df.to_excel('rmp1&2_references_manual.xlsx', sheet_name='analysis')
